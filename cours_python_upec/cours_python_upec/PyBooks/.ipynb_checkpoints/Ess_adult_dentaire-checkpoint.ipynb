# %% [markdown]
# # Modélisation Essentielle - Adultes

# %% [markdown]
# # Dentaire

# %%
# Path
# Local
WORKING_DIR = 'C:/Users/GV6074/Documents/0_Memoire_LC2019/1_Data'

DATA_SAS = WORKING_DIR + '/Tables_SAS_DTprev/'
PICKLE = WORKING_DIR + '/Pickles/'

# Import librairies

import pandas as pd
import numpy as np
import itertools
import statsmodels.api as sm
import scipy.stats as ss
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.externals import joblib 
import numpy as np

import utils_ml as uml

# Enlever la notation cientifique dans les Data Frames
pd.options.display.float_format = '{:.2f}'.format

# %%
#détection de la version de Python
import sys
if int(sys.version.split('.')[0]) ==3: #si c'est la 3 on importe le module importlib
    from importlib import reload

import utils_ml as uml

# %%
reload(uml)
# Out:
# <module 'utils_ml' from 'C:\\Users\\GV6074\\Documents\\0_Memoire_LC2019\\0_Code_python\\utils_ml.py'>

# %% [markdown]
# ###### Read data

# %%
# Export fait en notebook "Modélisation Essentielle"
adult_ess_dentaire = pd.read_pickle(PICKLE + "adult_ess_dentaire.pkl")

# %%
adult_ess_dentaire = adult_ess_dentaire.drop(['grand_poste'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a44eea6ff027> in <module>
# ----> 1 adult_ess_dentaire = adult_ess_dentaire.drop(['grand_poste'], axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %% [markdown]
# ##### Créer un index pour pouvoir faire facilement le lien avec les prédictions faites avec le glm en SAS

# %%
adult_ess_dentaire =adult_ess_dentaire.reset_index()

# %%
# On l'efface et on le crée à nouveau pour avoir des index numérées 0, 1, 2, .. 91959.
# Il y avait sinon les index originales de adulte_essent
adult_ess_dentaire = adult_ess_dentaire.drop(['index'], axis=1)

# %%
adult_ess_dentaire =adult_ess_dentaire.reset_index()

# %% [markdown]
# ##### <font color=orange>**Exporter à SAS pour réaliser le GLM**</font>

# %%
adult_ess_dentaire.to_csv(DATA_SAS + "adult_ess_dentaire.csv", index=True, encoding="latin-1")

# %%
uml.gr_ymean_xgroupby(adult_ess_dentaire ,"PP1", "age_benef", (30,8), \
                      "Dentaire: Moyenne de PP en fonction de l'âge", "20")

# %%
femmes= adult_ess_dentaire[adult_ess_dentaire['INDGENPER_BENEF'] == "F"]
hommes= adult_ess_dentaire[adult_ess_dentaire['INDGENPER_BENEF'] == "M"]

# %%
uml.gr_ymean_xgroupby(femmes ,"PP1", "age_benef", (30,8), \
                      "Dentaire - Femmes: Moyenne de PP en fonction de l'âge", "20")

# %%
uml.gr_ymean_xgroupby(hommes ,"PP1", "age_benef", (30,8), \
                      "Dentaire - Hommes: Moyenne de PP en fonction de l'âge", "20")

# %% [markdown]
# ## Analyse de corrélation

# %%
corr = uml.df_Cramer(adult_ess_dentaire[liste_features])

# %%
uml.heatMap(corr, "Corrélation des features : Adulte essentielle dentaire", (30, 30), 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-575b08bdafcb> in <module>
# ----> 1 uml.heatMap(corr, "Corrélation des features : Adulte essentielle dentaire", (30, 30), "Soins courants : Moyenne de PP en fonction de l'âge", "20")
#
# NameError: name 'corr' is not defined

# %% [markdown]
# ## Analyse de Y

# %%
print("Nombre d'assurés :", len(adult_ess_dentaire))
print("Nombre d'assurés avec un prime pure égal à zero :" , len(adult_ess_dentaire[adult_ess_dentaire['PP1']==0]))
print("Nombre d'assurés avec un prime pure suppérieure à zero :", len(adult_ess_dentaire[adult_ess_dentaire['PP1']>0]))
print("Pourcentage d'assurés avec une PP > 0 : ", (len(adult_ess_dentaire[adult_ess_dentaire['PP1']>0]) / len(adult_ess_dentaire)) * 100)
# Out:
# Nombre d'assurés : 91960
# Nombre d'assurés avec un prime pure égal à zero : 56611
# Nombre d'assurés avec un prime pure suppérieure à zero : 35349
# Pourcentage d'assurés avec une PP > 0 :  38.43953892996955

# %% [markdown]
# ### Répartition de la prime pure

# %%
sns.distplot(adult_ess_dentaire['PP1'], color='blue')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Zoom sur les PP supérieures à 0

# %%
sns.distplot(adult_ess_dentaire[adult_ess_dentaire['PP1']>0]['PP1'], color='blue')

# %%
sns.boxplot(adult_ess_dentaire['PP1'])

# %%
sns.distplot(adult_ess_dentaire[(adult_ess_dentaire['PP1']>0) & \
                                     (adult_ess_dentaire['PP1']<10000)]['PP1'], color='blue')

# %%
print(len(adult_ess_dentaire))
print(len(adult_ess_dentaire[adult_ess_dentaire['PP1']==0]))
print(len(adult_ess_dentaire[adult_ess_dentaire['PP1']>0]))
print(len(adult_ess_dentaire[(adult_ess_dentaire['PP1']>0) & (adult_ess_dentaire['PP1']<=100)]))
print(len(adult_ess_dentaire[(adult_ess_dentaire['PP1']>100) & (adult_ess_dentaire['PP1']<=1000)]))
print(len(adult_ess_dentaire[(adult_ess_dentaire['PP1']>1000) & (adult_ess_dentaire['PP1']<=10000)]))
print(len(adult_ess_dentaire[adult_ess_dentaire['PP1']>10000]))
# Out:
# 91960
# 56611
# 35349
# 25853
# 7579
# 1895
# 22

# %%
sns.distplot(adult_ess_dentaire[(adult_ess_dentaire['PP1']>+100) & \
                                     (adult_ess_dentaire['PP1']<=1000)]['PP1'], color='blue')

# %%
sns.distplot(adult_ess_dentaire[(adult_ess_dentaire['PP1']>0) & \
                                     (adult_ess_dentaire['PP1']<=1000)]['PP1'], color='blue')

# %% [markdown]
# On enlève le cas à 40000 €

# %%
adult_ess_dentaire = adult_ess_dentaire[adult_ess_dentaire['PP1']< 40000]
print(len(adult_ess_dentaire))
# Out:
# 91959

# %% [markdown]
# #### Regrouper zones 4 et 5

# %%
adult_ess_dentaire.groupby(['Zone']).size()
# Out:
# Zone
# 1    17705
# 2     8026
# 3    25016
# 4    38825
# 5     2387
# dtype: int64

# %%
adult_ess_dentaire.loc[adult_ess_dentaire['Zone']==5, 'Zone']= 4
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Vérification
adult_ess_dentaire.groupby(['Zone']).size()
# Out:
# Zone
# 1    17705
# 2     8026
# 3    25016
# 4    41212
# dtype: int64

# %% [markdown]
# #### Création de variable tranche d'âge (redefini) * genre

# %%
adult_ess_dentaire['tr_age_v2'] = adult_ess_dentaire['tr_age_v2'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
adult_ess_dentaire['age_genre'] = \
adult_ess_dentaire['INDGENPER_BENEF']+adult_ess_dentaire['tr_age_v2']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Laisser à nouveau tr_age_v2 comme numérique

# %%
adult_ess_dentaire['tr_age_v2'] = adult_ess_dentaire['tr_age_v2'].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Get dummies

# %%
adult_ess_dentaire = pd.get_dummies(adult_ess_dentaire,
                                         columns=['INDGENPER_BENEF', 'typeass',  'College', 'type_regime',
                                                  'tns_salarie', 'TYPE_FORMULE', 'age_genre'], 
               prefix=['genre', 'TYPEASS', 'College', 'regime', 'TS', 'formule', 'age_gen'])

# %%
adult_ess_dentaire.dtypes
# Out:
# index                              int64
# PP1                              float64
# COUTMOYEN                        float64
# FREQMOYEN                        float64
# SITUFAMBENEF                      object
# age_benef                          int32
# SCE                               object
# NIVEAU_FINAL2                      int32
# Zone                               int32
# tr_age_ben_num                     int32
# tr_age_v2                          int32
# genre_F                            uint8
# genre_M                            uint8
# TYPEASS_N                          uint8
# TYPEASS_O                          uint8
# College_Cadres                     uint8
# College_Divers                     uint8
# College_Ensemble du personnel      uint8
# College_Non cadres                 uint8
# College_TNS                        uint8
# regime_Alsace Moselle              uint8
# regime_Général                     uint8
# TS_Salariés                        uint8
# ...

# %%
adult_ess_dentaire.columns
# Out:
# Index(['index', 'PP1', 'COUTMOYEN', 'FREQMOYEN', 'SITUFAMBENEF', 'age_benef',
#        'SCE', 'NIVEAU_FINAL2', 'Zone', 'tr_age_ben_num', 'tr_age_v2',
#        'genre_F', 'genre_M', 'TYPEASS_N', 'TYPEASS_O', 'College_Cadres',
#        'College_Divers', 'College_Ensemble du personnel', 'College_Non cadres',
#        'College_TNS', 'regime_Alsace Moselle', 'regime_Général', 'TS_Salariés',
#        'TS_TNS', 'formule_O', 'formule_S', 'age_gen_F1', 'age_gen_F2',
#        'age_gen_F3', 'age_gen_F4', 'age_gen_F5', 'age_gen_F6', 'age_gen_F7',
#        'age_gen_F8', 'age_gen_M1', 'age_gen_M2', 'age_gen_M3', 'age_gen_M4',
#        'age_gen_M5', 'age_gen_M6', 'age_gen_M7', 'age_gen_M8'],
#       dtype='object')

# %%
# liste de features avec âge, tranche d'âge et tranche d'age*genre
liste_features_1 =['age_benef', 'NIVEAU_FINAL2', 'Zone', 'tr_age_v2', 'genre_F', 'genre_M', 'TYPEASS_N', 'TYPEASS_O',
               'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 'College_Non cadres', 
               'College_TNS', 'regime_Alsace Moselle', 'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O',
               'formule_S', 'age_gen_F1', 'age_gen_F2', 'age_gen_F3', 'age_gen_F4', 'age_gen_F5', 'age_gen_F6',
               'age_gen_F7', 'age_gen_F8', 'age_gen_M1', 'age_gen_M2', 'age_gen_M3', 'age_gen_M4', 'age_gen_M5',
               'age_gen_M6', 'age_gen_M7', 'age_gen_M8']

# liste de features avec âge et tranche d'age*genre
liste_features_2 =['age_benef', 'NIVEAU_FINAL2', 'Zone', 'genre_F', 'genre_M', 'TYPEASS_N', 'TYPEASS_O',
               'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 'College_Non cadres', 
               'College_TNS', 'regime_Alsace Moselle', 'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O',
               'formule_S', 'age_gen_F1', 'age_gen_F2', 'age_gen_F3', 'age_gen_F4', 'age_gen_F5', 'age_gen_F6',
               'age_gen_F7', 'age_gen_F8', 'age_gen_M1', 'age_gen_M2', 'age_gen_M3', 'age_gen_M4', 'age_gen_M5',
               'age_gen_M6', 'age_gen_M7', 'age_gen_M8']

# liste de features avec seulement tranche d'âge
liste_features_3 =['NIVEAU_FINAL2', 'Zone', 'tr_age_v2', 'genre_F', 'genre_M', 'TYPEASS_N', 'TYPEASS_O',
               'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 'College_Non cadres', 
               'College_TNS', 'regime_Alsace Moselle', 'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O',
               'formule_S']

# liste de features avec seulement âge
liste_features_4 =['age_benef', 'NIVEAU_FINAL2', 'Zone', 'genre_F', 'genre_M', 'TYPEASS_N', 'TYPEASS_O',
               'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 'College_Non cadres', 
               'College_TNS', 'regime_Alsace Moselle', 'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O',
               'formule_S']

# %% [markdown]
# ## Classification en deux classes : PP1 > 0 ou PP1 = 0

# %%
adult_ess_dentaire.loc[adult_ess_dentaire['PP1']==0, 'PP1_clas'] = 0
adult_ess_dentaire.loc[adult_ess_dentaire['PP1']!=0, 'PP1_clas'] = 1

# %% [markdown]
# ### Régression Logistique (reglog)

# %%
from sklearn.linear_model import LogisticRegression

# %%
feat_reglog = adult_ess_dentaire[['age_benef', 'NIVEAU_FINAL2', 'Zone', 'tr_age_ben_num', 'genre_F', 
                                   'genre_M', 'TYPEASS_N', 'TYPEASS_O', 'SCE_Conjoint', 'SCE_Salarie',
                                   'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 
                                   'College_Non cadres', 'College_TNS', 'regime_Alsace Moselle',
                                   'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O', 'formule_S', 
                                   'age_gen_10F', 'age_gen_10M', 'age_gen_1F', 'age_gen_1M', 'age_gen_2F', 
                                   'age_gen_2M', 'age_gen_3F', 'age_gen_3M', 'age_gen_4F', 'age_gen_4M', 
                                   'age_gen_5F', 'age_gen_5M', 'age_gen_6F', 'age_gen_6M', 'age_gen_7F', 
                                   'age_gen_7M', 'age_gen_8F', 'age_gen_8M', 'age_gen_9F', 'age_gen_9M']]

# %%
targ_reglog = adult_ess_dentaire['PP1_clas']

# %%
from sklearn.model_selection import train_test_split
X_train_reglog, X_test_reglog, y_train_reglog, y_test_reglog = \
train_test_split(feat_reglog, targ_reglog, random_state=42, test_size=0.3, stratify= targ_reglog)

# %%
print(X_train_reglog.shape)
print(X_test_reglog.shape)
print(y_train_reglog.shape)
print(y_test_reglog.shape)
# Out:
# (64402, 41)
# (27602, 41)
# (64402,)
# (27602,)

# %% [markdown]
# Centrer et réduire les features

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_reglog_scaled = scaler.fit_transform(X_train_reglog)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int32 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int32 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# Grid Search

# %%
param_grid_reglog = [
{'penalty': ['l2'], 'C': [0.01, 0.1, 1, 10, 100, 1000], 'class_weight': ['balanced', None], 
 'max_iter': [100, 1000], 'n_jobs' : [-1]
}]

reglog_grid = LogisticRegression(random_state=42)

grid_search_reglog = GridSearchCV(reglog_grid, param_grid_reglog, cv=5)

# %%
grid_search_reglog.fit(X_train_reglog , y_train_reglog)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# ...

# %%
grid_search_reglog.best_estimator_
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
#           penalty='l2', random_state=42, solver='warn', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
reg_log = LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
          penalty='l2', random_state=42, solver='warn', tol=0.0001,
          verbose=0, warm_start=False)

# %%
reg_log.fit(X_train_reglog, y_train_reglog)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
#           penalty='l2', random_state=42, solver='warn', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [raw]
# Enregistrer le modèle

# %%
joblib.dump(reg_log, "reg_log.pkl")
# Out:
# ['reg_log.pkl']

# %%
# and later... 
reg_log= joblib.load("reg_log.pkl")

# %% [markdown]
# ##### Prédictions

# %%
y_test_pred_reglog = reg_log.predict(X_test_reglog)

# %%
reg_log.score(X_test_reglog, y_test_reglog)
# Out:
# 0.6170929642779509

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test_reglog, y_test_pred_reglog))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.97      0.76     16993
#          1.0       0.52      0.05      0.09     10609
#
#    micro avg       0.62      0.62      0.62     27602
#    macro avg       0.57      0.51      0.42     27602
# weighted avg       0.58      0.62      0.50     27602

# %%
proba_test_reglog = reg_log.predict_proba(X_test_reglog)[:,1]

# %%
proba_test_reglog.min()
# Out:
# 0.16702721823969802

# %%
X_temp = uml.pred_X(X_test_reglog, y_test_reglog, reg_log)

# %%
X_temp['proba'] = reg_log.predict_proba(X_test_reglog)[:,1]

# %%
X_temp = X_temp[X_temp['y_obs'] == 1]

# %%
print(len(X_temp[X_temp['y_obs'] == 1]))
print(len(X_temp[X_temp['y_pred']==1]))
# Out:
# 10609
# 530

# %% [markdown]
# ### Création d'un DF avec les classes balancées

# %%
adult_ess_dentaire_pos = adult_ess_dentaire[adult_ess_dentaire['PP1'] > 0]
adult_ess_dentaire_zero = adult_ess_dentaire[adult_ess_dentaire['PP1']==0]
print(len(adult_ess_dentaire_pos))
print(len(adult_ess_dentaire_zero))
# Out:
# 35361
# 56643

# %% [markdown]
# On conserve tous les assurés dont la PP > 0 mais on sélectionne aléatoirement le même nombre (35361) d'assurés avec la PP = 0

# %%
adult_ess_dentaire_zero_sample = adult_ess_dentaire_zero.sample(n=35361)

# %%
balanced_ad_ess_dent = pd.concat([adult_ess_dentaire_zero_sample, adult_ess_dentaire_pos])

# %%
print("Nombre d'assurés :", len(balanced_ad_ess_dent))
print("Nombre d'assurés avec un prime pure égal à zero :" , len(balanced_ad_ess_dent[balanced_ad_ess_dent['PP1']==0]))
print("Nombre d'assurés avec un prime pure suppérieure à zero :", len(balanced_ad_ess_dent[balanced_ad_ess_dent['PP1']>0]))
print("Pourcentage d'assurés avec une PP > 0 : ", (len(balanced_ad_ess_dent[balanced_ad_ess_dent['PP1']>0]) / len(balanced_ad_ess_dent)) * 100)
# Out:
# Nombre d'assurés : 70722
# Nombre d'assurés avec un prime pure égal à zero : 35361
# Nombre d'assurés avec un prime pure suppérieure à zero : 35361
# Pourcentage d'assurés avec une PP > 0 :  50.0

# %%
balanced_ad_ess_dent.loc[balanced_ad_ess_dent['PP1']==0, 'PP1_clas'] = 0
balanced_ad_ess_dent.loc[balanced_ad_ess_dent['PP1']!=0, 'PP1_clas'] = 1

# %%
feat_reglog_balance = balanced_ad_ess_dent[['age_benef', 'NIVEAU_FINAL2', 'Zone', 'tr_age_ben_num', 'genre_F', 
                                   'genre_M', 'TYPEASS_N', 'TYPEASS_O', 'SCE_Conjoint', 'SCE_Salarie',
                                   'College_Cadres', 'College_Divers', 'College_Ensemble du personnel', 
                                   'College_Non cadres', 'College_TNS', 'regime_Alsace Moselle',
                                   'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O', 'formule_S', 
                                   'age_gen_10F', 'age_gen_10M', 'age_gen_1F', 'age_gen_1M', 'age_gen_2F', 
                                   'age_gen_2M', 'age_gen_3F', 'age_gen_3M', 'age_gen_4F', 'age_gen_4M', 
                                   'age_gen_5F', 'age_gen_5M', 'age_gen_6F', 'age_gen_6M', 'age_gen_7F', 
                                   'age_gen_7M', 'age_gen_8F', 'age_gen_8M', 'age_gen_9F', 'age_gen_9M']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-bcf40414a348> in <module>
# ----> 1 feat_reglog_balance = balanced_ad_ess_dent[['age_benef', 'NIVEAU_FINAL2', 'Zone', 'tr_age_ben_num', 'genre_F',
#       2                                    'genre_M', 'TYPEASS_N', 'TYPEASS_O', 'SCE_Conjoint', 'SCE_Salarie',
#       3                                    'College_Cadres', 'College_Divers', 'College_Ensemble du personnel',
#       4                                    'College_Non cadres', 'College_TNS', 'regime_Alsace Moselle',
#       5                                    'regime_Général', 'TS_Salariés', 'TS_TNS', 'formule_O', 'formule_S']]
#
# NameError: name 'balanced_ad_ess_dent' is not defined

# %%
targ_reglog_balance = balanced_ad_ess_dent['PP1_clas']

# %%
X_train_reglog_balance, X_test_reglog_balance, y_train_reglog_balance, y_test_reglog_balance = \
train_test_split(feat_reglog_balance, targ_reglog_balance, random_state=42, test_size=0.3, stratify= targ_reglog_balance)

# %% [markdown]
# Grid Search

# %%
param_grid_reglog_balance = [
{'penalty': ['l2'], 'C': [0.01, 0.1, 1, 10, 100, 1000], 'class_weight': ['balanced', None], 
 'max_iter': [100, 1000], 'n_jobs' : [-1]
}]

reglog_grid_balance = LogisticRegression(random_state=42)

grid_search_reglog_balance = GridSearchCV(reglog_grid_balance, param_grid_reglog_balance, cv=5)

# %%
grid_search_reglog_balance.fit(X_train_reglog_balance , y_train_reglog_balance)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# ...

# %%
grid_search_reglog_balance.best_estimator_
# Out:
# LogisticRegression(C=10, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=-1, penalty='l2', random_state=42,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
reg_log_balance = LogisticRegression(C=10, class_weight='balanced', dual=False,
          fit_intercept=True, intercept_scaling=1, max_iter=100,
          multi_class='warn', n_jobs=-1, penalty='l2', random_state=42,
          solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
reg_log_balance.fit(X_train_reglog_balance, y_train_reglog_balance)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# LogisticRegression(C=10, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=-1, penalty='l2', random_state=42,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
y_test_pred_reglog_balance = reg_log_balance.predict(X_test_reglog_balance)

# %%
reg_log_balance.score(X_test_reglog_balance, y_test_reglog_balance)
# Out:
# 0.558467266814347

# %% [markdown]
# Pas d'amélioration --> Manque de variables ou de feature engineering ?

# %% [markdown]
# ### Modélisation de la PP directement

# %%
feat_1 = adult_ess_dentaire[liste_features_1]
targ_1 = adult_ess_dentaire['PP1']

# %% [markdown]
# ###### Train test split

# %%
from sklearn.model_selection import train_test_split

X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(feat_1, targ_1, test_size=0.3, random_state=42)

# %%
for i in [X_train_1, X_test_1, y_train_1, y_test_1]:
    print(i.shape)
# Out:
# (64371, 35)
# (27588, 35)
# (64371,)
# (27588,)

# %% [markdown]
# # XGBoost (xgb_d)

# %%
import xgboost as xgb

# %% [markdown]
# ##### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_xgb_d = [
{'objective': ['reg:linear', 'reg:tweedie'], 'colsample_bytree': [0.3, 0.5], 'learning_rate': [0.1, 0.5, 1],
 'max_depth': [3 ,4 ,5], 'alpha': [0, 10, 20], 'n_estimators': [500], 'n_jobs': [-1]
}]

grad_xgb_d = xgb.XGBRegressor(random_state=42)

grid_search_xgb_d = GridSearchCV(grad_xgb_d, param_grid_xgb_d, cv=5)

# %%
grid_search_xgb_d.fit(X_train_1, y_train_1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [14:40:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [14:41:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [14:41:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
grid_search_xgb_d.best_estimator_
# Out:
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
xgb_regres_d = xgb.XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=0.3, gamma=0,
       importance_type='gain', learning_rate=0.1, max_delta_step=0,
       max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
       n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=None, subsample=1, verbosity=1)

# %%
xgb_regres_d.fit(X_train_1, y_train_1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %% [markdown]
# ##### Enregistrer modèle

# %%
joblib.dump(xgb_regres_d, "xgb_regres.pkl")
# Out:
# ['xgb_regres.pkl']

# %% [markdown]
# ###### Prédictions et mesures de performance

# %% [markdown]
# ##### Test

# %%
y_test_pred_xgb_d = xgb_regres_d.predict(X_test_1)

# %%
uml.regression_metrics(y_test_1, y_test_pred_xgb_d)
# Out:
# Y_test mean :  85.80348418487013
# Y_pred mean :  84.99552
# RMSE :  400.4026368373638
# MSE :  160322.27158631381
# Variance expliquée :  0.02299985080777356
# R² :  0.02299587264635916

# %% [markdown]
# ##### Train

# %%
y_train_pred_xgb_d = xgb_regres_d.predict(X_train_1)

# %%
uml.regression_metrics(y_train_1, y_train_pred_xgb_d)
# Out:
# Y_test mean :  87.11376334610263
# Y_pred mean :  85.2574
# RMSE :  416.44858996370857
# MSE :  173429.42808276106
# Variance expliquée :  0.0369027199224522
# R² :  0.03688358243007883

# %% [markdown]
# ##### Valeurs y observées et prédits

# %%
y_test_1_2 = y_test_1.to_frame()

# %%
sns.distplot(y_test_1_2, color='blue')
plt.title("Valeurs y observées en test")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Valeurs y observées en test')

# %%
print(sns.distplot(y_test_pred_xgb_d, color='blue'))
plt.title("Valeurs y prédits en test")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Valeurs y prédits en test')

# %%
min(y_test_pred_xgb_d)
# Out:
# 2.0673277

# %% [markdown]
# ##### Valeurs observées jusqu'à 1000

# %%
y_test_xgb_d2 = y_test_xgb_d.to_frame()
print(sns.distplot(y_test_xgb_d2[y_test_xgb_d2['PP1']<=1000], color='blue'))
plt.title("Valeurs y observées en test, jusqu'à 1000")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, "Valeurs y observées en test, jusqu'à 1000")

# %% [markdown]
# ###### Résidus

# %%
uml.residus(xgb_regres_d, y_test_1, X_test_1, 1)

# %% [markdown]
# ##### Filtre résidus < 5000

# %%
df_temp = y_test_1 - xgb_regres_d.predict( X_test_1)

# %%
df_temp = df_temp.to_frame()

# %%
df_temp = df_temp.rename(columns={'PP1':'res'})

# %%
sns.set(style="white", context="talk")
plt.figure(figsize=(15,10))
sns.scatterplot(data=df_temp[df_temp['res']<5000], markers=".", alpha=1)

# %%
sns.set(style="white", context="talk")
plt.figure(figsize=(15,10))
sns.scatterplot(data=df_temp[df_temp['res']<2000], markers=".", alpha=1)

# %% [markdown]
# ##### Feature importance

# %%
fi_xgb_d = pd.DataFrame(xgb_regres_d.feature_importances_,index=X_test_1.columns, 
                 columns=['importance']).sort_values('importance', ascending=False)

# %%
fi_xgb_d
# Out:
#                                importance
# NIVEAU_FINAL2                        0.26
# tr_age_v2                            0.09
# age_benef                            0.05
# College_Non cadres                   0.04
# Zone                                 0.03
# age_gen_F7                           0.03
# age_gen_F1                           0.03
# College_Divers                       0.03
# age_gen_F2                           0.03
# TS_TNS                               0.03
# age_gen_M8                           0.03
# College_Cadres                       0.03
# age_gen_M2                           0.03
# formule_S                            0.02
# age_gen_M1                           0.02
# age_gen_M5                           0.02
# age_gen_M3                           0.02
# formule_O                            0.02
# age_gen_F3                           0.02
# age_gen_F8                           0.02
# TS_Salariés                          0.02
# ...

# %% [markdown]
# ##### Graph validation univariée

# %%
df_test_xgb_d = uml.pred_X(X_test_1, y_test_1, xgb_regres_d)

# %% [markdown]
# ###### Age

# %%
uml.val_uni(df_test_xgb_d, 'age_benef', 'y_obs', 'y_pred', (20, 10))

# %% [markdown]
# ###### Niveau de garantie

# %%
uml.val_uni(df_test_xgb_d, 'NIVEAU_FINAL2', 'y_obs', 'y_pred', (20, 10))

# %% [markdown]
# ###### Genre

# %%
uml.val_uni(df_test_xgb_d, 'genre_F', 'y_obs', 'y_pred', (20, 10))

# %% [markdown]
# ###### Trânche d'âge

# %%
uml.val_uni(df_test_xgb_d, 'tr_age_v2', 'y_obs', 'y_pred', (20, 10))

# %% [markdown]
# ###### Zone

# %%
uml.val_uni(df_test_xgb_d, 'Zone', 'y_obs', 'y_pred', (20, 10))

# %% [markdown]
# ###### Validation en echantillons aleatoires taille 3500

# %%
X_test_1_2 = X_test_1.copy()
X_test_1_2['PP1'] = y_test_1

# %%
ech_xgb_d1_1 = X_test_1_2.sample(n=3500)
ech_xgb_d1_2 = X_test_1_2.sample(n=3500)
ech_xgb_d1_3 = X_test_1_2.sample(n=3500)
ech_xgb_d1_4 = X_test_1_2.sample(n=3500)
ech_xgb_d1_5 = X_test_1_2.sample(n=3500)

# %%
feat_ech_xgb_d1_1 = ech_xgb_d1_1[liste_features_1]
feat_ech_xgb_d1_2 = ech_xgb_d1_2[liste_features_1]
feat_ech_xgb_d1_3 = ech_xgb_d1_3[liste_features_1]
feat_ech_xgb_d1_4 = ech_xgb_d1_4[liste_features_1]
feat_ech_xgb_d1_5 = ech_xgb_d1_5[liste_features_1]

# %%
targ_ech_xgb_d1_1 = ech_xgb_d1_1['PP1']
targ_ech_xgb_d1_2 = ech_xgb_d1_2['PP1']
targ_ech_xgb_d1_3 = ech_xgb_d1_3['PP1']
targ_ech_xgb_d1_4 = ech_xgb_d1_4['PP1']
targ_ech_xgb_d1_5 = ech_xgb_d1_5['PP1']

# %% [markdown]
# ###### Créer un DF avec les prédictions

# %%
val_ech1 = uml.pred_X(feat_ech_xgb_d1_1, targ_ech_xgb_d1_1, xgb_regres_d)
val_ech2 = uml.pred_X(feat_ech_xgb_d1_2, targ_ech_xgb_d1_2, xgb_regres_d)
val_ech3 = uml.pred_X(feat_ech_xgb_d1_3, targ_ech_xgb_d1_3, xgb_regres_d)
val_ech4 = uml.pred_X(feat_ech_xgb_d1_4, targ_ech_xgb_d1_4, xgb_regres_d)
val_ech5 = uml.pred_X(feat_ech_xgb_d1_5, targ_ech_xgb_d1_5, xgb_regres_d)

# %% [markdown]
# ###### Stats validations

# %%
uml.stats_pred_X(val_ech1)
# Out:
# Moyenne de y_obs 78.89243875617233
# Moyenne de y_pred 84.40190124511719
#
#
# Somme total de y_obs 276123.5356466038
# Somme total de y_pred 295406.62
#
#
# Somme des écarts -19283.08279402424
# Moyenne des écarts -5.509452226864054
#
#
# % Pourcentage de la somme des écarts sur la somme des Y_obs :  -6.983498436259218

# %%
uml.stats_pred_X(val_ech2)
# Out:
# Moyenne de y_obs 80.33802759852232
# Moyenne de y_pred 85.16743469238281
#
#
# Somme total de y_obs 281183.0965948289
# Somme total de y_pred 298085.62
#
#
# Somme des écarts -16902.530947190022
# Moyenne des écarts -4.829294556339982
#
#
# % Pourcentage de la somme des écarts sur la somme des Y_obs :  -6.011218722562737

# %%
uml.stats_pred_X(val_ech3)
# Out:
# Moyenne de y_obs 82.66639051231094
# Moyenne de y_pred 84.37606048583984
#
#
# Somme total de y_obs 289332.36679308896
# Somme total de y_pred 295316.3
#
#
# Somme des écarts -5983.929434366152
# Moyenne des écarts -1.709694124104613
#
#
# % Pourcentage de la somme des écarts sur la somme des Y_obs :  -2.0681852848649513

# %%
uml.stats_pred_X(val_ech4)
# Out:
# Moyenne de y_obs 79.1557188526774
# Moyenne de y_pred 84.13044738769531
#
#
# Somme total de y_obs 277045.0159843721
# Somme total de y_pred 294456.28
#
#
# Somme des écarts -17411.24965040305
# Moyenne des écarts -4.974642757258005
#
#
# % Pourcentage de la somme des écarts sur la somme des Y_obs :  -6.284628362123361

# %%
uml.stats_pred_X(val_ech5)
# Out:
# Moyenne de y_obs 95.4821437359446
# Moyenne de y_pred 86.67767333984375
#
#
# Somme total de y_obs 334187.5030758064
# Somme total de y_pred 303371.88
#
#
# Somme des écarts 30815.64345833474
# Moyenne des écarts 8.804469559524229
#
#
# % Pourcentage de la somme des écarts sur la somme des Y_obs :  9.221063975975362

# %% [markdown]
# # Reg. log

# %%
adult_ess_dentaire.to_excel(WORKING_DIR + '/adult_ess_dentaire.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-301-2eef49b62eb5> in <module>
# ----> 1 adult_ess_dentaire.to_excel(WORKING_DIR + '/adult_ess_dentaire.xlsx', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ...

# %%
adult_ess_dentaire.loc[adult_ess_dentaire['PP1']==0, 'PP_bin'] = 1
adult_ess_dentaire.loc[adult_ess_dentaire['PP1']!=0, 'PP_bin'] = 0

# %%
feat_reglog = adult_ess_dentaire[liste_features]
# Création d'une target binnaire : 0 ou 1
targ_reglog = adult_ess_dentaire['PP_bin']

# %%
# Eliminer une catégorie des variables dummys pour éviter multicolinéarité
feat_reglog= feat_reglog.drop(['genre_M', 'TYPEASS_O', 'College_TNS', 'TS_TNS', 'regime_Général', 'SCE_Salarie',
                               'SCE_Conjoint', 'formule_S', 'tr_age_ben_num', 
                              'age_gen_10F', 'age_gen_10M', 'age_gen_1F', 'age_gen_1M', 'age_gen_2F', 
                                   'age_gen_2M', 'age_gen_3F', 'age_gen_3M', 'age_gen_4F', 'age_gen_4M', 
                                   'age_gen_5F', 'age_gen_5M', 'age_gen_6F', 'age_gen_6M', 'age_gen_7F', 
                                   'age_gen_7M', 'age_gen_8F', 'age_gen_8M', 'age_gen_9F', 'age_gen_9M'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train_reglog, X_test_reglog, y_train_reglog, y_test_reglog = \
train_test_split(feat_reglog, targ_reglog, test_size=0.3, random_state=42)

# %%
for i in [X_train_reglog, X_test_reglog, y_train_reglog, y_test_reglog]:
    print(i.shape)
# Out:
# (64403, 12)
# (27602, 12)
# (64403,)
# (27602,)

# %% [markdown]
# ###### Ajouter la constante

# %%
import statsmodels

# %%
X_train_reglog_const = statsmodels.tools.add_constant(X_train_reglog)

# %% [markdown]
# ###### Régression Logistique

# %%
from statsmodels.discrete.discrete_model import Logit

# %%
mlr = Logit(y_train_reglog, X_train_reglog_const)

# %%
res_mlr = mlr.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.656049
#          Iterations 5

# %%
print(res_mlr.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                 PP_bin   No. Observations:                64403
# Model:                          Logit   Df Residuals:                    64391
# Method:                           MLE   Df Model:                           11
# Date:                Mon, 19 Aug 2019   Pseudo R-squ.:                 0.01457
# Time:                        15:50:54   Log-Likelihood:                -42251.
# converged:                       True   LL-Null:                       -42876.
#                                         LLR p-value:                3.869e-261
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.6667      0.056     29.769      0.000       1.557       1.776
# ...

# %%
print("Residual deviance =", -2*res_mlr.llf)
print("LR (signif. globale) =", res_mlr.llr)
print("p-value =", res_mlr.llr_pvalue)
print("AIC =", res_mlr.aic)
# Out:
# Residual deviance = 84502.99843297941
# LR (signif. globale) = 1249.2767046367953
# p-value = 3.8691675199876232e-261
# AIC = 84526.99843297941

# %% [markdown]
# ##### Prédictions

# %%
# Ajouter la constante dans test
X_test_reglog_const = statsmodels.tools.add_constant(X_test_reglog)

# %%
# Faire des prédictions
y_test_reglog_pred = res_mlr.predict(X_test_reglog_const)

# %%
y_test_reglog_pred2 = pd.DataFrame({'Proba'  : y_test_reglog_pred})

# %%
y_test_reglog_pred2['exp_proba'] = np.exp(y_test_reglog_pred2['Proba'])

# %%
y_test_reglog_pred2
# Out:
#          Proba  Pred_clas  Obs_clas  exp_proba
# 639901    0.54       1.00      1.00       1.71
# 208781    0.68       1.00      1.00       1.97
# 479469    0.65       1.00      1.00       1.92
# 582173    0.68       1.00      0.00       1.98
# 52709     0.67       1.00      1.00       1.95
# 687749    0.61       1.00      1.00       1.84
# 1224069   0.46       0.00      1.00       1.58
# 531405    0.55       1.00      1.00       1.73
# 889581    0.55       1.00      1.00       1.73
# 1052485   0.61       1.00      0.00       1.83
# 431285    0.53       1.00      0.00       1.70
# 393749    0.62       1.00      0.00       1.85
# 1345053   0.62       1.00      1.00       1.86
# 841821    0.67       1.00      0.00       1.96
# 1041269   0.53       1.00      1.00       1.69
# 201141    0.66       1.00      1.00       1.94
# 203669    0.64       1.00      0.00       1.90
# 941917    0.77       1.00      1.00       2.16
# 837277    0.65       1.00      1.00       1.91
# ...

# %%
# Prédictions de classe : Si Proba >= 0.5 --> Classe 1 (cad PP1 = 0)
#                            Proba < 0.5 --> Classe 0 (cad PP1 != 0)
y_test_reglog_pred2.loc[y_test_reglog_pred2['Proba'] >= 0.5, 'Pred_clas'] = 1
y_test_reglog_pred2.loc[y_test_reglog_pred2['Proba'] < 0.5, 'Pred_clas'] = 0

# %%
# Ajouter la classe observée
y_test_reglog_pred2['Obs_clas'] = y_test_reglog

# %% [markdown]
# ###### Classification report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_reglog_pred2['Obs_clas'], y_test_reglog_pred2['Pred_clas']))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.06      0.10     10664
#          1.0       0.62      0.97      0.75     16938
#
#    micro avg       0.61      0.61      0.61     27602
#    macro avg       0.56      0.51      0.43     27602
# weighted avg       0.58      0.61      0.50     27602

# %% [markdown]
# ###### Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test_reglog_pred2['Obs_clas'], y_test_reglog_pred2['Pred_clas'])
# Out:
# array([[  608, 10056],
#        [  589, 16349]], dtype=int64)

# %% [markdown]
# Les résultats du classification report ne sont pas très bons. On elimine les variables non significatives

# %% [markdown]
# ###### On enleve les variables nos significatives

# %%
# On reprend les DF feat_reglog et targ_reglog et on enleve de feat_reglog les variables non singnificatives 
feat_reglog2 = feat_reglog.drop(['College_Cadres', 'College_Divers', 'College_Ensemble du personnel',
                                'College_Non cadres', 'TS_Salariés'], axis=1)

# %%
X_train_reglog2, X_test_reglog2, y_train_reglog2, y_test_reglog2 = \
train_test_split(feat_reglog2, targ_reglog, test_size=0.3, random_state=42)

# %%
for i in [X_train_reglog2, X_test_reglog2, y_train_reglog2, y_test_reglog2]:
    print(i.shape)
# Out:
# (64403, 7)
# (27602, 7)
# (64403,)
# (27602,)

# %%
# Ajouter la constante
X_train_reglog_const2 = statsmodels.tools.add_constant(X_train_reglog2)

# %% [markdown]
# ###### Regression logistique

# %%
mlr2 = Logit(y_train_reglog2, X_train_reglog2)

# %%
res_mlr2 = mlr2.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.669718
#          Iterations 4

# %%
print(res_mlr2.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                 PP_bin   No. Observations:                64403
# Model:                          Logit   Df Residuals:                    64396
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 19 Aug 2019   Pseudo R-squ.:               -0.005964
# Time:                        20:53:30   Log-Likelihood:                -43132.
# converged:                       True   LL-Null:                       -42876.
#                                         LLR p-value:                     1.000
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# age_benef                 0.0007      0.001      1.137      0.256      -0.000       0.002
# NIVEAU_FINAL2             0.0077      0.006      1.210      0.226      -0.005       0.020
# ...

# %% [markdown]
# ## XGBoost avec objective = Tweedie

# %%
feat_xgb_twd = adult_ess_dentaire[liste_features]
# Eliminer les features corréléés, innecesaires
feat_xgb_twd = feat_xgb_twd.drop(['genre_M', 'TYPEASS_O', 'SCE_Conjoint', 'SCE_Salarie',
                                  'TS_Salariés', 'TS_TNS', 'formule_S'], axis=1)
targ_xgb_twd = adult_ess_dentaire['PP1']

# %%
X_train_xgb_twd , X_test_xgb_twd , y_train_xgb_twd , y_test_xgb_twd  = \
train_test_split(feat_xgb_twd , targ_xgb_twd , test_size=0.3, random_state=42)

# %%
for i in [X_train_xgb_twd , X_test_xgb_twd , y_train_xgb_twd , y_test_xgb_twd]:
    print(i.shape)
# Out:
# (64403, 34)
# (27602, 34)
# (64403,)
# (27602,)

# %% [markdown]
# ###### Grid Seach

# %%
param_grid_xgb_twd = [
{'objective' : ['reg:tweedie'], 'colsample_bytree': [0.3, 0.5], 'learning_rate': [0.1, 0.5, 1],
 'max_depth': [3 ,4 ,5], 'alpha': [0, 10,20], 'n_estimators': [500], 'n_jobs': [-1]
}]

grad_xgb_twd = xgb.XGBRegressor(random_state=42)

grid_search_xgb_twd = GridSearchCV(grad_xgb_twd, param_grid_xgb_twd, cv=5)

grid_search_xgb_twd.fit(X_train_xgb_twd, y_train_xgb_twd)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ...

# %%
grid_search_xgb_twd.best_estimator_
# Out:
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
xgb_regres_twd = xgb.XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=0.3, gamma=0,
       importance_type='gain', learning_rate=0.1, max_delta_step=0,
       max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
       n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=None, subsample=1, verbosity=1)

# %%
xgb_regres_twd.fit(X_train_xgb_twd, y_train_xgb_twd)
# Out:
# XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=-1, nthread=None, objective='reg:tweedie', random_state=42,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %% [markdown]
# ###### Prédictions et mesures de performance

# %% [markdown]
# ##### Test

# %%
y_test_pred_xgb_twd = xgb_regres_twd.predict(X_test_xgb_twd)

# %%
uml.regression_metrics(y_test_xgb_twd, y_test_pred_xgb_twd)
# Out:
# Y_test mean :  84.94074949691421
# Y_pred mean :  86.83135
# RMSE :  379.83905053368983
# MSE :  144277.704310335
# Variance expliquée :  0.017166091695215324
# R² :  0.017141742074681665

# %% [markdown]
# ##### Train

# %%
y_train_pred_xgb_twd = xgb_regres_twd.predict(X_train_xgb_twd)

# %%
uml.regression_metrics(y_train_xgb_twd, y_train_pred_xgb_twd)
# Out:
# Y_test mean :  88.1598942683426
# Y_pred mean :  86.02902
# RMSE :  454.9615664299463
# MSE :  206990.02692839043
# Variance expliquée :  0.035997290477615684
# R² :  0.0359761432708815

# %% [markdown]
# ##### Valeurs y observées et prédits

# %%
sns.distplot(y_test_xgb_twd, color='blue')
plt.title("Valeurs y observées en test")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Valeurs y observées en test')

# %%
print(sns.distplot(y_test_pred_xgb_twd, color='blue'))
plt.title("Valeurs y prédits en test")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Valeurs y prédits en test')

# %% [markdown]
# ## Random Forest

# %%
feat_4 = adult_ess_dentaire[liste_features_4]
targ_4 = adult_ess_dentaire['PP1']

# %%
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(feat_4, targ_4, test_size=0.3, random_state=42)

# %%
for i in [X_train_4, X_test_4, y_train_4, y_test_4]:
    print(i.shape)
# Out:
# (64371, 18)
# (27588, 18)
# (64371,)
# (27588,)

# %% [markdown]
# ##### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid_d = [
{'n_estimators': [500], 'max_features': [10, 13, 15], 'max_depth' : [None, 5, 10], 'n_jobs' : [-1]
}]

forest_grid_d = RandomForestRegressor(random_state=42)

grid_search_d = GridSearchCV(forest_grid_d, param_grid_d, cv=5)

# %%
grid_search_d.fit(X_train_4, y_train_4)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'n_estimators': [500], 'max_features': [10, 13, 15], 'max_depth': [None, 5, 10], 'n_jobs': [-1]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
grid_search_d.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features=13, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=500, n_jobs=-1, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %%
rf_d = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
           max_features=13, max_leaf_nodes=None, min_impurity_decrease=0.0,
           min_impurity_split=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=500, n_jobs=-1, oob_score=False, random_state=42,
           verbose=0, warm_start=False)

# %%
rf_d.fit(X_train_4, y_train_4)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features=13, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=500, n_jobs=-1, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %% [markdown]
# ###### Enregistrer modèle

# %%
joblib.dump(rf_d, "rf_d.pkl")
# Out:
# ['rf_d.pkl']
