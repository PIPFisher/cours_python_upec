# %% [markdown]
# <br>
# <div align="right">Enseignant : Aric Wizenberg</div>
# <div align="right">E-mail : icarwiz@yahoo.fr</div>
# <div align="right">Année : 2018/2019</div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:darkgreen">Master 2 MASERATI - Cours de Python</span></div><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:24px;color:#e60000">Installation des logiciels</span></div><br><br>
# <hr>

# %% [markdown]
# # Installation des logiciels
#
# ## Connaitre le type de son processeur
#
# Pour commencer, il est important de connaitre le type d'adressage de son système : 32 bits (alias x86) ou 64 bits?
#
# Cette information est disponible, sous Windows, en allant dans les informations du système.
# Pour y aller, on peut :
# - utiliser le raccourci clavier : **touche Windows + Pause**)
# - aller dans le **Panneau de configuration**, élément **Système**
#
# L'info est disponible à la ligne **Type du système**
#
# ---
#
# ![System.png](attachment:System.png)

# %% [markdown]
# ## Désinstallation éventuelle d'Anaconda
#
# Ensuite, vérifier qu'Anaconda n'est pas déjà installé.
#
# Pour s'en assurer, aller sur la page **Programmes** du **Panneau de configuration**
#
# S'il est installé, il devrait y avoir une ligne nommée (les lettres étant remplacés par des chiffres) :
#
# *Python X.Y.Z (AnacondaX R.S.T NN-bit)*.
#
# ---
#
# - **Si c'est le cas**, merci de le désinstaller au préalable en suivant la procédure ci-dessous. Cela évitera les bugs et incompatibilités et vous permettra d'avoir la version la plus à jour...
#
# >Pour désinstaller la version, cliquer bouton droit sur la ligne en question, puis sur **désinstaller**.
# >
# >Ensuite il suffit de passer les étapes les unes après les autres en cliquant sur **Suivant**/**Désinstaller**.
#
# ![step_00.png](attachment:step_00.png)
#
# ---
# - **Sinon** passer directement à la section suivante

# %% [markdown]
# ## Téléchargement d'Anaconda
#
# Il faut tout d'abord, télécharger le fichier d'installation depuis https://www.anaconda.com/download/
#
# **En version 3.X, obligatoirement.** La dernière version est la 3.7
#
# La version par défaut (le gros bouton **Download**) est la version 64 bits.
#
# Pour ceux qui ont un système en 32-bits, utiliser plutôt le lien **32-Bit Graphical Installer** en-dessous du bouton download.
#
# ---
#
# ![2018-12-28%2015_24_52-Downloads%20-%20Anaconda.png](attachment:2018-12-28%2015_24_52-Downloads%20-%20Anaconda.png)

# %% [markdown]
# ## Installation d'Anaconda
#
# Une fois téléchargé, **exécuter** ce fichier exécutable.
#
# Puis suivre la procédure suivante...
#
# ---
#
# ![2018-12-28%2015_53_17-Open%20File%20-%20Security%20Warning.png](attachment:2018-12-28%2015_53_17-Open%20File%20-%20Security%20Warning.png)
#
# ---
#
# ![2018-12-28%2015_42_22-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_42_22-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)

# %% [markdown]
# ![2018-12-28%2015_42_24-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_42_24-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)
#
# ---
#
# <div class="alert alert-block alert-danger">
# <b>Attention</b> à bien sélectionner une installation seulement pour l'utilisateur actuel (Just me) dans la boite de dialogue suivante
# </div>
#
# ---
#
# ![2018-12-28%2015_42_26-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_42_26-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Important :</b> Mettre le programme dans <b>C:\Users\{nom d'utilisateur}\Anaconda3</b>, où {nom d'utilisateur} est votre nom d'utilisateur Windows:
# </div>
#
# ---
#
# ![2018-12-28%2015_43_45-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_43_45-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)
#
# ---
#
# <div class="alert alert-block alert-danger">
# <b>Attention :</b> Sur la page suivate laisser la première case décochée et la deuxième cochée, puis cliquer sur Installer
# </div>
#
# ---
#
# ![2018-12-28%2015_43_50-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_43_50-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)

# %% [markdown]
# Lorsque l'installation est finie, il faut cliquer sur Suivant :
#
# ---
#
#
#
# ![2018-12-28%2015_53_35-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_53_35-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)
#
#
# Installer ensuite Microsoft VSCode, ça peut toujours être utile :
#
# ---
#
# ![2018-12-28%2015_53_45-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_53_45-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)
#
# ---
#
# **NB :** Si l'installation de VS Code échoue pour une raison ou une autre, tant pis, ce n'est pas un composant essentiel.

# %% [markdown]
# Puis décocher les deux cases de la page suivante et cliquer sur Terminer :
#
# ---
#
# ![2018-12-28%2015_53_52-Anaconda3%202018.12%20%2864-bit%29%20Setup.png](attachment:2018-12-28%2015_53_52-Anaconda3%202018.12%20%2864-bit%29%20Setup.png)

# %% [markdown]
# ## Installation de Notepad++
#
# Si ce n'est pas déjà fait, il faut maintenant installer Notepad++, un programme qui devrait être installé sur tout ordinateur !
#
# - Si vous avez déjà Notepad++, vous pouvez directement passer à la [section suivante](#Exécution-du-script-d'initialisation)
#
# - Sinon, il faut l'installer...
#
# Commencer par le télécharger à l'adresse suivante :
# https://notepad-plus-plus.org/download
#
# Télécharger le "Notepad++ Installer XX-bit" correspondant à votre système (32 ou 64 bits)
#
# ---
#
# ![Npp_step_00.png](attachment:Npp_step_00.png)
#
#
# Puis l'installer, la procédure est similaire à celle utilisée pour Anaconda.
#
# Il n'y a cette fois rien de plus à faire que de valider chaque étape de la procédure d'installation l'une après l'autre en gardant les paramètres par défaut.

# %% [markdown]
# # Création du dossier PyBooks
#
# Sous l'explorateur Windows, aller dans votre dossier :
#
# **C:\Users\{nom d'utilisateur}**
#
# Puis créer dans ce dossier un sous-dossier intitulé **PyBooks**
#
# Copier ensuite le fichier **Installation_NB.ipynb** dans ce sous-dossier PyBooks

# %% [markdown]
# # Premiers pas sur Notebook
#
# ## Lancement de Jupyter Notebook
#
# Il faut maintenant lancer **Jupyter Notebook** en utilisant le raccourci du même nom qui doit se trouver dans un dossier **Anaconda3** de votre Menu Démarrer.
#
# ---
#
# ![2018-12-28%2015_40_04-Start%20menu.png](attachment:2018-12-28%2015_40_04-Start%20menu.png)
#
# ---
#
# Une **fenêtre de commande** s'ouvre : la **fenêtre de commande de Jupyter Notebook** (cf. ci-dessous), **il faut toujours la laisser ouverte tant que l'on travaille avec Jupyter Notebook**, on peut la réduire où la laisser ouverte en arrière-plan...
#
# ---
#
# ![2018-12-28%2016_07_57-Jupyter%20Notebook.png](attachment:2018-12-28%2016_07_57-Jupyter%20Notebook.png)
#
# ---

# %% [markdown]
# Le navigateur Internet par défaut s'ouvre ensuite avec l'**interface de Jupyter Notebook** :
#
# ---
#
# ![step_34.png](attachment:step_34.png)

# %% [markdown]
# Un dossier **PyBooks** devrait être présent dans la liste.
#
# Entrer dans ce dossier en cliquant sur son nom
#
# ![step_41.png](attachment:step_41.png)

# %% [markdown]
# Puis cliquer sur le nom du fichier **Installation_NB.ipynb** pour continuer la procédure
#
# ![2018-09-30%2018_07_14-PyBooks_.png](attachment:2018-09-30%2018_07_14-PyBooks_.png)
#
# <div class="alert alert-block alert-info">
# Nous continuerons avec la section suivante plus tard...
#
# Pour l'instant il faut suivre les instructions affichées dans cette nouvelle fenêtre qui vient de s'ouvrir.
# </div>

# %% [markdown]
# ## Activation des extensions
#
# Tout d'abord il faut redémarrer Jupyter Notebook, pour ça :
# 1. Fermer la fenêtre de console de Jupyter Notebook (la fenêtre sur fond noir)
# 2. Puis relancer Jupyter Notebook en utilisant l'icône du menu démarrer
#
# ---
#
# Pour ce premier vrai démarrage de Jupyter Notebook, il faut aller activer quelques extensions très pratiques
#
# Aller dans l'onglet ***Nbextensions***
#
# Cocher les cases suivantes :
# * Table of Contents (2) (permet d'ajouter un sommaire)
# * Collapsible Headings (permet de replier les sections)
# * ExecuteTime (permet d'indiquer le temps d'exécution des cellules de code)
# * Variable Inspector (permet d'afficher la valeur des variables en mémoire)
#
# ---
#
# ![step_35.png](attachment:step_35.png)

# %% [markdown]
# # Bienvenue !
#
# Une fois les cases cochées, il suffit de retourner sur l'écran d'accueil en cliquant sur l'onglet **Files** en haut de l'écran.
#
# On pourrait alors créer un nouveau Notebook en cliquant en haut à droite sur le bouton New, puis sur Python 3.
#
# Vous avez enfin fini toutes les procédures d'installation et de configuration !
#
# Je vous souhaite la bienvenue à ce cours de Python !
#
# ![python-logo.png](attachment:python-logo.png)
