# %% [markdown]
# <br>
# <div align="right">Enseignant : Aric Wizenberg</div>
# <div align="right">E-mail : icarwiz@yahoo.fr</div>
# <div align="right">Année : 2018/2019</div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:darkgreen">Master 2 MASERATI - Cours de Python</span></div><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:24px;color:#e60000">Composants de base</span></div><br><br>
# <hr>

# %% [markdown]
# ## 1 Le langage Python et son pack
#
# Contrairement à ce que l'on pense généralement, le nom **Python** ne vient pas d'ici :
#
# <div align="center"><img src="attachment:shutterstock_368881394.jpg" style="width:500px"></div>

# %% [markdown]
# Mais de là :
# <div align="center"><img src="attachment:monty-python-and-the-holy-grail-still2.jpg" style="width:500px"></div>
#
# Image du film *Monty Python : the Quest for the Holy Grail*

# %% [markdown]
# ![python-logo.png](attachment:python-logo.png)
#
# Python est un langage de programmation crée en **1991** par un codeur néerlandais, **Guido van Rossum**.
#
# Le langage en est à sa troisième génération. **Python 3** est sorti en 2008.
#
# Actuellement les dernières versions stables sont la v3.6 et la v3.7 (sortie en juin 2018), la v3.8 est en cours de développement.
#
# La deuxième génération de Python, sortie en 2000, **Python 2** est encore parfois utilisée. Mais cette génération ne sera officiellement plus maintenue à partir de 2020.
#
# Sauf lorsque vous n'avez pas d'autre choix (utilisation d'anciennes bibliothèques), je vous déconseille fortement de l'utiliser.
#
# Dans ce cours, seul Python 3 sera abordé.
#
# <div class="alert alert-block alert-info"><b>Pour votre curiosité : </b> <a href=../infos/van_rossum.pdf> Interview du créateur de Python dans le journal Le Monde</a></div>
#
# <div class="alert alert-block alert-info"><b>Pour aller plus loin :</b> <a href=http://apprendre-python.com/page-syntaxe-differente-python2-python3-python-differences> Différences de syntaxe entre Python 2 et 3 </a></div>

# %% [markdown]
# Python, c'est :
# - un langage plutôt simple à comprendre et écrire
# - un langage généraliste puissant permettant de coder virtuellement tout ce qu'il est possible de coder sur un ordinateur.
# - l'un des 5 langages les plus utilisés dans le monde (avec les langages de type C, le Java, le Javascript, le R, le Ruby...).
# - l'un des deux poids lourds (avec R) des Data Sciences
#
# ---
#
# <div class="alert alert-block alert-info"><b>Pour aller plus loin :</b> <a href=../infos/r-vs-python-216-2.png> Comparatif entre R et Python pour les Data Science </a></div>

# %% [markdown]
# ## 2 Les modules (ou bibliothèques)
#
# Python possède un très grand nombre de bibliothèques (libraries en anglais) :
# * Pandas : gestion de tables de données
# * Numpy : fonctions et objets de calcul numérique (calculs matriciels et objets matrices par exemple)
# * Scipy : fonctions et objets scientifique (fonctions statistiques complexes par exemple)
# * Matplotlib : fonctions d'affichage de graphiques
# * Sklearn : fonctions en rapport avec le Machine Learning, biblio de référence pour tous les trucs du Data Scientist moderne
#
# Nous y reviendrons plus tard...

# %% [markdown]
# ## 3 Les environnement de Développement Intégré (EDI/IDE)
#
# Un Environnement de Développement Intégré (EDI, IDE en anglais) est un logiciel contenant un éditeur de texte et tout ce qui est nécessaire pour exécuter et tester du code informatique.
#
# Il existe un grand nombre d'IDE différents, des plus simples (IDLE par exemple) aux plus complexes (PyCharm par exemple).
#
# Il faut voir cela comme pour le traitement de texte : on pourrait rédiger un rapport avec le Bloc-Notes de Windows, mais un logiciel comme Microsoft Word dispose d'un grand nombre de fonctionnalités supplementaires (vérificateur d'orthographe, outils de mise en page, création automatique de titres, possibilité d'ajouter des graphiques, etc.).

# %% [markdown]
# Pour simplifier, il y a deux grandes familles d'IDE :
# - Ceux qui fonctionnent sur le mode de **l'exécution intégrale**, le mode classique des programmeurs. Lorsque l'on est dans ce mode, à chaque fois que l'on veut tester son code, l'ensemble du code est exécuté de la 1ère à la dernière ligne. Les éléments ne sont gardés en mémoire que le temps de l'exécution.
# - Ceux qui fonctionnent sur le mode de **l'exécution interactive**, c'est-à-dire que l'on teste son code par étape sans perdre les résultats de l'exécution des étapes précédentes.

# %% [markdown]
# L'exécution interactive est très importante en Data sciences : on peut penser à un bout de code qui analyserait une base de données. Si cette base de données est longue à charger en mémoire, l'exécution interactive permet de ne faire l'opération de chargement qu'une seule fois (par session de travail), alors qu'en exécution intégrale il faut la recharger à chaque exécution du code.
#
# On peut dire pour simplifier que :
# - l'**exécution intégrale** est le mode de prédilection des programmeurs informatique, car elle permet de créer des logiciels plus complexes, et de type produit fini.
# - l'**exécution interactive** est le mode de prédilection des Data Scientists, car elle permet d'avancer en explorant des données.
#
# En Python, l'exécution interactive passe par un outil qui s'appelle **IPython** (Interactive Python)

# %% [markdown]
# ### 3.1 Bloc-Note et Notepad++
#
# Dans les faits il n'est pas obligatoire d'utiliser un IDE pour coder en Python.
#
# Il suffit de faire un fichier avec une extension **.py** contenant du code en Python et de l'exécuter en utilisant la commande **python** localisée dans le dossier d'installation de Python (ou d'Anaconda)
#
# On peut donc très bien utiliser le Bloc-Notes de Windows pour coder ! Même si personne ne fait jamais ça...

# %% [markdown]
# Mais bon, à la rigueur, on pourrait utiliser une version très améliorée du Bloc-Notes qui s'appelle Notepad++ (un logiciel qu'il est très vivement recommandé d'avoir sur sa machine)
#
# <br><div align="center"><img src="attachment:Notepad++.png" style="height:400px"></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Lien pour le téléchargement :</b> <a href=https://notepad-plus-plus.org/download> Site officiel de Notepad++ </a></div>

# %% [markdown]
# ### 3.2 Les IDE classiques : PyCharm Community
#
# PyCharm Community est très complet (mais un peu difficile à maitriser), il permet de développer des logiciels complexes, il fonctionne en mode **exécution intégrale**. Il dispose d'un très grand nombre d'outils d'aide au développement.
#
# <br><div align="center"><img src="attachment:Pycharm.png" style="height:400px"></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Lien pour le téléchargement :</b> <a href=https://www.jetbrains.com/pycharm/download> Site officiel de PyCharm (la version gratuite est "Community") </a></div>

# %% [markdown]
# ### 3.3 Les IDE de type R-Studio : Spyder et Rodeo
#
# L'avantage essentiel avec ces IDE est de pouvoir travailler en **mode interactif**. Ils permettent d'avoir un inspecteur de données, ce qui est très pratique.
#
# #### Spyder
#
# <br><div align="center"><img src="attachment:Spyder.png" style="height:400px"></div>

# %% [markdown]
# #### Rodeo
#
# <br><div align="center"><img src="attachment:Rodeo.png" style="height:400px"></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Lien pour le téléchargement :</b> <a href=http://blog.yhat.com/posts/introducing-rodeo.html> Site officiel de Rodeo </a></div>

# %% [markdown]
# ### 3.4 Jupyter et ses IDE
#
# #### Jupyter
#
# Jupyter est une **plateforme de développement web multi-langage**, d'ailleurs le nom *Jupyter* est composé de **Ju** pour [Julia](https://fr.wikipedia.org/wiki/Julia_(langage)), **Pyt** pour [Python](https://fr.wikipedia.org/wiki/Python_(langage)) et R pour... [R](https://fr.wikipedia.org/wiki/R_(langage)).
#
# Les noyaux (sections logicielles) correspondants de ces trois langages sont maintenus par l'équipe de développement de Jupyter. Le noyau utilisé pour Python s'appelle **IPython** (I comme interactive), qui est aussi le nom du projet précurseur de Jupyter.
#
# Mais Jupyter permet aussi d'utiliser plusieurs autres langages, en utilisant des noyaux créés par la communauté : [Java](https://fr.wikipedia.org/wiki/Java_(langage)), [Octave](https://fr.wikipedia.org/wiki/GNU_Octave), [Scala](https://fr.wikipedia.org/wiki/Scala_(langage))...
#
# <div class="alert alert-block alert-info">
# <b>Pour aller plus loin:</b> <br>
# <a href=https://github.com/jupyter/jupyter/wiki/Jupyter-kernels> Liste complète des noyaux Jupyter pour les autres langages</a><br>
# <a href=https://jupyter.org> Site officiel du projet Jupyter</a><br>
# <a href=https://jupyter-notebook.readthedocs.io> Site officiel de la documentation de Jupyter Notebook</a>
# </div>
#
# #### Jupyter Notebook
#
# Jupyter Notebook est l'IDE qui est utilisé dans le cadre de ce cours, il fonctionne en **mode interactif**. Il sera présenté tout au long de ce cours.

# %% [markdown]
# #### Jupyter Lab
#
# Jupyter Lab est une déclinaison de Jupyter plus proche de Spyder, Rodéo ou RStudio, il fonctionne aussi en **mode interactif**. Il est pour l'instant à un stade de développement insuffisamment avancé, mais d'ici un an ou deux, aucun doute qu'il deviendra une référence...
#
# <br><div align="center"><img src="attachment:jupyterlab-demo.png" style="height:400px"></div>

# %% [markdown]
# ## 4 Les distributions : Anaconda
#
# Une distribution est un pack qui rassemble l'ensemble des éléments précédemment évoqués en un seule pack. La distribution de référence pour les Data Science sur Python est **Anaconda**, elle rassemble : Python, beaucoup de bibliothèques, Jupyter et Spyder...
#
# <br><div align="center"><img src="attachment:Anaconda-Distribution-Diagram.png" style="height:400px"></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Site officiel d'Anaconda : </b> <a href=https://www.anaconda.com> https://www.anaconda.com </a></div>
