# %% [markdown]
# <br>
# <div align="right">Enseignant : Aric Wizenberg</div>
# <div align="right">E-mail : icarwiz@yahoo.fr</div>
# <div align="right">Année : 2018/2019</div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:darkgreen">Master 2 MASERATI - Cours de Python</span></div><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:24px;color:#e60000">Examen final</span></div><br><br>
# <hr>

# %% [markdown]
# **Lisez attentivement l'ensemble des instructions des exercices ainsi que les instructions ci-dessous**
#
# (attention : elles ont été modifiées par rapport à celles du devoir qui était à faire chez soi).
#
# - N'ajoutez aucune cellule dans ce Notebook, et n'en supprimez aucune.
# - Si vous n'arrivez pas à modifier une cellule, c'est qu'il n'y a pas de raison que vous la modifiiez.
#
# - Les exercices sont indépendant les uns des autres (même s'il est conseillé de les faire dans l'ordre).
# - En revanche les questions d'un même exercice doivent être traitées dans l'ordre indiqué, et toutes les cellules de l'exercice doivent être exécutées les unes après les autres, afin que tout fonctionne correctement.
#
# - N'oubliez pas de taper vos réponses en dessous des endroits portant la mention :
#     - `# Ecrivez votre code ci-dessous` lorsqu'une réponse en code Python est attendue,
#     - "# Ecrivez votre réponse ci-dessous" lorsqu'une réponse en français est attendue,
# - Vous verrez que lorsque, dans une cellule de code, la définition d'un objet est attendue :
#     - S'il s'agit d'une variable, il sera écrit en début de cellule `nom_de_variable = None`, dans ce cas, il faudra que votre code redéfinisse cette variable
#     - S'il s'agit d'une fonction, il sera écrit en début de cellule `def nom_de_fonction(): pass`, dans ce cas, il faudra que votre code redéfinisse cette fonction
# - Ne vous préoccupez pas des cellules où il est écrit `# Cellule vide`, vous n'avez rien à faire avec ces cellules
# - Sauf lorsque c'est clairement spécifié, vous n'avez pas le droit d'utiliser de modules dans ce devoir
# - Après chaque exercice que vous finissez, assurez-vous que tout fonctionne comme prévu :
#     - Redémarrez d'abord le noyau (dans la barre de menus, cliquez sur Kernel$\rightarrow$Restart)
#     - Puis exécutez toutes les cellules de votre exercice une à une, depuis le début, en vérifiant bien qu'il n'y ait pas d'erreur d'exécution ou de syntaxe que vous n'auriez pas traité (en dehors bien sûr des erreurs provoquées par les cellules de vérification à la suite de réponses que vous n'auriez pas fourni, mais dans ce cas-là, normal que ça entraine une erreur...)
# - Vous avez le droit d'utiliser Internet (mais il est probable que ce soit une perte de temps), ainsi que tout document à votre disposition.
# - En revanche il est strictement interdit de communiquer entre vous par quelque moyen que ce soit.
# - Vous avez 2 heures. Bon courage !
#
# **Commencez par indiquer votre nom en définissant la variable mon_nom ci-dessous :**

# %%
mon_nom = ''

# %% [markdown]
# ---

# %% [markdown]
# # Exercice 1 (2 points)
#
# Soit le texte suivant, assigné à la variable **MON_TEXTE** :

# %%
MON_TEXTE = '''La statistique descriptive est la branche des statistiques qui regroupe les nombreuses techniques utilisées pour décrire un ensemble relativement important de données 
L'objectif de la statistique descriptive est de décrire, c'est-à-dire de résumer ou représenter, par des statistiques, les données disponibles quand elles sont nombreuses'''

# %% [markdown]
# ## Question 1.1 (1 point)
#
# Quel est le type de la variable ***MON_TEXTE*** ?
#
# Quelle est la longueur de son contenu ?
#
# Ne répondez pas directement, utilisez une fonction de Python pour obtenir les infos et définir les variables présentes dans la cellule

# %%
type_mon_texte = None
longueur_mon_texte = None
# Ecrivez votre code ci-dessous

# %%
type_mon_texte

# %%
longueur_mon_texte

# %% [markdown]
# ## Question 1.2 (1 point)
# Créez une variable (***mon_texte_clean***) dont le contenu est le même que celui de ***MON_TEXTE***, mais où les **virgules** et **retours à la ligne** ont été **supprimés**.
#
# Puis, découpez **mon_texte_clean** sur la base des espaces et mettre le résultat dans la variable ***mon_texte_decoupe***.

# %%
mon_texte_clean = None
mon_texte_decoupe = None
# Ecrivez votre code ci-dessous

# %%
mon_texte_clean

# %%
mon_texte_decoupe

# %% [markdown]
# # Exercice 2 (5 points)
# Soit la liste de mots suivantes :

# %%
MA_LISTE_DE_MOTS = [
    'La', 'statistique', 'descriptive', 'est', 'la', 'branche', 'des', 'statistiques', 'qui', 'regroupe', 
    'les', 'nombreuses', 'techniques', 'utilisées', 'pour', 'décrire', 'un', 'ensemble', 'relativement', 
    'important', 'de', 'données', 'L\'objectif', 'de', 'la', 'statistique', 'descriptive', 'est', 'de', 
    'décrire', 'c\'est-à-dire', 'de', 'résumer', 'ou', 'représenter', 'par', 'des', 'statistiques', 
    'les', 'données', 'disponibles', 'quand', 'elles', 'sont', 'nombreuses'
]

# %% [markdown]
# ## Question 2.1 (1 point)
# Créez une liste ***ma_nouvelle_liste*** identique à ***MA_LISTE_DE_MOTS***
#
# Puis ajoutez le mot "économétrie" à ***ma_nouvelle_liste***
#
# Attention, ***MA_LISTE_DE_MOTS*** ne doit pas être impactée par cette opération

# %%
ma_nouvelle_liste = None
# Ecrivez votre code ci-dessous

# %%
len(ma_nouvelle_liste)

# %%
len(MA_LISTE_DE_MOTS)

# %% [markdown]
# ## Question 2.2 (1,5 points)
# Soit toujours cette même liste de mots :

# %%
MA_LISTE_DE_MOTS = [
    'La', 'statistique', 'descriptive', 'est', 'la', 'branche', 'des', 'statistiques', 'qui', 'regroupe', 
    'les', 'nombreuses', 'techniques', 'utilisées', 'pour', 'décrire', 'un', 'ensemble', 'relativement', 
    'important', 'de', 'données', 'L\'objectif', 'de', 'la', 'statistique', 'descriptive', 'est', 'de', 
    'décrire', 'c\'est-à-dire', 'de', 'résumer', 'ou', 'représenter', 'par', 'des', 'statistiques', 
    'les', 'données', 'disponibles', 'quand', 'elles', 'sont', 'nombreuses']

# %% [markdown]
# Créez un dictionnaire ***dict_positions*** qui à chaque mot de ***MA_LISTE_DE_MOTS*** associe sa position de **première occurence** au sein de cette liste.
#
# Attention :
# - la position du premier mot est 0
# - vous n'avez pas le droit d'utiliser la méthode index
# - ne remplacez pas la position du premier mot lorsqu'un même mot est trouvé plusieurs fois au sein de la liste.

# %%
dict_positions = None
# Ecrivez votre code ci-dessous

# %%
dict_positions

# %%
len(dict_positions)

# %%
dict_positions['de']

# %% [markdown]
# ## Question 2.3 (1,5 points)
# Ecrivez une fonction ***compte_voyelles*** qui prend en entrée une chaine de caractères et renvoi le **nombre de voyelles** contenues dans cette chaine de caractères.
# - utilisez pour vous aider la chaine de caractères ***VOYELLES*** définie ci-dessous
# - utilisez une boucle dans cette fonction

# %%
VOYELLES = 'AEIOUYaeiouyáâäèéêëîïóôöùûüÿ'

# %%
def compte_voyelles():
    pass

# Ecrivez votre code ci-dessous

# %%
compte_voyelles('examen')

# %% [markdown]
# Créez une boucle pour définir le dictionnaire ***dict_voyelles*** qui à chaque mot (en tant que clé) de ***MA_LISTE_DE_MOTS*** associe le nombre de voyelles contenue dans ce mot (en tant que valeur). Utilisez pour cela la fonction précédemment définie.

# %%
dict_voyelles = None
# Ecrivez votre code ci-dessous

# %%
dict_voyelles

# %%
dict_voyelles['statistique']

# %% [markdown]
# ## Question 2.4 (1 point)
# Soit la liste de valeurs suivante :

# %%
LISTE_NOMBRES = [5, 10, 2, '5', 3, 25]

# %% [markdown]
# Définir une fonction ***carre*** qui prend une liste de valeurs en entrée et renvoie l'ensemble de ces valeurs au carré.
#
# Attention :
# - la liste **LISTE_NOMBRES** qui sera passée en entrée de la fonction dans la cellule suivante ne doit pas être modifiée par l'application de cette fonction
# - votre fonction doit inclure un **bloc de traitement d'erreur** pour traiter le cas où l'un des nombres de la liste en entrée est sous forme de chaine de caractères

# %%
def carre():
    pass
# Ecrivez votre code ci-dessous

# %%
carre(LISTE_NOMBRES)

# %%
carre(['1', 2, 3, '4'])

# %% [markdown]
# # Exercice 3 (2 points)
#
# ## Question 3.1 (0,5 point)
# Chargez le module ***numpy*** et assignez à ***reponse*** la valeur de $\Pi$ (PI) en utilisant ce module

# %%
reponse = None
# Ecrivez votre code ci-dessous

# %%
reponse

# %% [markdown]
# ## Question 3.2 (1,5 points)
# Définir les deux fonctions suivantes :
# - ***surface_cercle***, qui, ***à un rayon*** associe la surface d'un cercle : cette surface est égale à $ \Pi$ (PI) multiplié par le **rayon en entrée mis au carré**,
# - ***volume_cylindre***, qui, ***à un rayon ET une hauteur*** (mettez les arguments dans cet ordre) associe le volume d'un cylindre : ce volume est égal à la **surface du cercle du rayon en entrée** multiplié par la **hauteur en entrée**,
#
# Attention : utilisez ***surface_cercle*** dans la définition de ***volume_cylindre***

# %%
def surface_cercle():
    pass

def volume_cylindre():
    pass

# Ecrivez votre code ci-dessous

# %%
surface_cercle(5)

# %%
volume_cylindre(5, 8)

# %%
# Cellule vide

# %% [markdown]
# # Exercice 4 (3 points)
# Soit le chemin de fichier suivant :

# %%
CHEMIN_FICHIER = 'input/metadonnees.json'

# %% [markdown]
# ## Question 4.1 (1 point)
# Ouvrez le fichier localisé à l'emplacement indiqué dans ***CHEMIN_FICHIER***
#
# Puis chargez son contenu dans la variable ***contenu_fichier***
#
# Attention : n'utilisez pas le module json, il s'agit d'ouvrir le fichier comme un **fichier texte normal**.

# %%
contenu_fichier = None
# Ecrivez votre code ci-dessous

# %%
len(contenu_fichier)

# %%
contenu_fichier[:80]

# %% [markdown]
# ##  Question 4.2 (1 point)
#
# Chargez maintenant le contenu de ce fichier JSON dans la variable ***dict_variables*** en utilisant le module adapté à cette opération (que vous devrez donc importer au préalable).
#
# La variable ***dict_variables*** contiendra donc un dictionnaire...

# %%
dict_variables = None
# Ecrivez votre code ci-dessous

# %%
# dict_variables

# %% [markdown]
# Assignez maintenant à la variable ***cles_dict*** les clés du dictionnaire qui est contenu comme valeur pour la clé ***OverallCond*** (il s'agit donc d'un dictionnaire contenu dans un dictionnaire)

# %%
cles_dict = None
# Ecrivez votre code ci-dessous

# %%
cles_dict

# %% [markdown]
# ## Question 4.3 (1 point)
#
# Assignez à ***liste_variables*** une **liste de tuples** (de tuples à deux éléments, autrement dit de couples) à partir de ***dict_variables*** avec:
# - Pour premier élément de chaque couple, **le nom de la variable**
# - Pour second élément de chaque couple, **un booléen** dont la valeur est vraie si la variable considérée dispose de modalités, faux sinon

# %%
liste_variables = None
# Ecrivez votre code ci-dessous

# %%
len(liste_variables)

# %%
liste_variables[3]

# %% [markdown]
# # Exercice 5 (5 points)
# Chargez les modules en exécutant la cellule suivante :

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Soit le chemin de fichier suivant :

# %%
CHEMIN_FICHIER = 'input/VentesMaisons.xlsx'

# %% [markdown]
# ## Question 5.1 (1 point)
#
# Chargez en mémoire le contenu de ce fichier en tant que DataFrame en l'assignant à ***df_ventes***

# %%
df_ventes = None
# Ecrivez votre code ci-dessous

# %%
df_ventes.shape

# %% [markdown]
# Affichez maintenant les informations principales de ce DataFrame

# %%
# Ecrivez votre code ci-dessous

# %%
# Cellule vide

# %% [markdown]
# ## Question 5.2 (1 point)
# Créez un dictionnaire ***dict_conversion*** qui :
# - à la clé ***Grvl*** associe l'entier ***0***
# - à la clé ***Pave*** associe l'entier ***1***
#
# Puis utilisez ce dictionnaire pour créer une nouvelle Series ***dStreet*** à partir des valeurs de la Series ***Street*** au sein du DataFrame ***df_ventes*** (qui sera donc modifié). ***dStreet*** sera donc une variable dichotomique.

# %%
dict_conversion = None
# Ecrivez votre code ci-dessous

# %%
dict_conversion

# %%
df_ventes.head()

# %% [markdown]
# ## Question 5.3 (1 point)
# Créez une fonction ***fonction_de_categorisation*** qui prend en entrée une valeur numérique et qui renvoie les chaines de caractères : (attention à bien respecter les majuscules)
# - ***Petit*** si la valeur est strictement inférieur à 10000
# - ***Moyen*** si la valeur est comprise entre 10000 (inclus) et 25000 (exclus)
# - ***Grand*** si la valeur est supérieure ou égale à 25000
#
# Utilisez cette fonction pour créer une nouvelle Série ***LotAreaCate*** à partir de la Series ***LotArea*** au sein du DataFrame ***df_ventes*** (qui sera donc modifié)

# %%
def fonction_de_categorisation():
    pass
# Ecrivez votre code ci-dessous

# %%
fonction_de_categorisation(10000)

# %%
df_ventes.head()

# %% [markdown]
# ## Question 5.4 (1 point)
# Créez la Series ***PyDateSold*** en utilisant la Series ***DateSold*** et en convertissant ses valeurs dans le type python **DateTime**, toujours au sein du DataFrame ***df_ventes*** (qui sera donc modifié)
#
# Puis créez dans ce DataFrame la Series ***Annee*** à partir de ***PyDateSold*** (cette Series devra donc ne contenir que l'année de la date contenue dans ***PyDateSold***)

# %%
# Ecrivez votre code ci-dessous

# %%
df_ventes['PyDateSold'].head()

# %%
df_ventes[['DateSold', 'PyDateSold', 'Annee']].head()

# %% [markdown]
# ## Question 5.5 (1 point)
# Soit le DataFrame défini ci-dessous :

# %%
valdict = [
    (10, 'Very Excellent'),
    (9, 'Excellent'),
    (8, 'Very Good'),
    (7, 'Good'),
    (6, 'Above Average'),
    (5, 'Average'),
    (4, 'Below Average'),
    (3, 'Fair'),
    (2, 'Poor'),
    (1, 'Very Poor')]

df_conversion = pd.DataFrame(valdict, columns=['valeur', 'OverallCond_desc']).set_index('valeur')

# %%
df_conversion

# %% [markdown]
# Assignez à la variable ***df_ventes_plus*** le résultat d'une opération de fusion entre le DataFrame ***df_ventes*** et le DataFrame ***df_conversion*** en utilisant la Series ***OverallCond*** de ***df_ventes***.

# %%
df_ventes_plus = None
# Ecrivez votre code ci-dessous

# %%
df_ventes_plus['OverallCond_desc'].unique()

# %% [markdown]
# # Exercice 6 (3 points)
# Chargez les modules en exécutant la cellule suivante :

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Chargez le DataFrame modifié ***df_ventes*** en exécutant la cellule suivante :

# %%
df_ventes = pd.read_pickle('input/df_ventes.pickle')

# %% [markdown]
# ## Question 6.2 (1 point)
#
# Créez deux versions filtrées du DataFrame ***df_ventes***:
# - ***df_reponse_filtre_simple***, qui est le résultat d'un filtrage simple répondant à une **unique condition** :
#     - ***Annee*** est égale à ***2007***
# - ***df_reponse_filtre_simple***, qui est le résultat d'un filtrage complexe répondant à **deux conditions en même temps** :
#     - ***Annee*** est égale à ***2007***
#     - ***LotAreaCate*** est égale à ***Petit***

# %%
df_reponse_filtre_simple = None
df_reponse_filtre_complexe = None
# Ecrivez votre code ci-dessous

# %%
df_reponse_filtre_simple.head()

# %%
df_reponse_filtre_complexe.head()

# %% [markdown]
# ## Question 6.2 (1 point)
# Affichez un graphique représentant la distribution de la Series ***LotArea*** de ***df_ventes***

# %%
# Ecrivez votre code ci-dessous

# %%
# Cellule vide

# %% [markdown]
# Affichez un graphique représentant le nuage de points entre les Series ***SalePrice*** et ***LotArea*** de ***df_ventes***

# %%
# Ecrivez votre code ci-dessous

# %%
# Cellule vide

# %% [markdown]
# ## Question 6.3 (1 point)
# Assignez à ***df_tcd*** le tableau croisé dynamique (Pivot Table) établi à partir de ***df_ventes*** avec les caractéristiques suivantes :
# - En colonnes: les années (Series ***Annee***)
# - En lignes: les différents états des maisons (Series ***OverallCond_desc***)
# - Les valeurs devant être la **moyenne** des **prix de vente** (Series ***SalePrice***) pour chacun de ces croisements

# %%
df_tcd = None
# Ecrivez votre code ci-dessous

# %%
df_tcd

# %% [markdown]
# ## Question 6.4 (1 point bonus)
# En utilisant le module **seaborn** que vous aurez chargé au préalable, créez une **heatmap** à partir de la matrice des corrélations de ***df_ventes***

# %%
# Ecrivez votre code ci-dessous

# %%
# Cellule vide
